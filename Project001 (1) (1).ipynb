# %%
import pandas as pd
location = "DC_Properties.csv"
df = pd.read_csv(location)
df
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (18,19,20,21,22,23,24,33,34,35,37,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 0                0       4          0      Warm Cool  Y        2.0      8
# 1                1       3          1      Warm Cool  Y        2.0     11
# 2                2       3          1  Hot Water Rad  Y        2.0      9
# 3                3       3          1  Hot Water Rad  Y        2.0      8
# 4                4       2          1      Warm Cool  Y        1.0     11
# 5                5       3          2  Hot Water Rad  Y        1.0     10
# 6                6       1          0      Warm Cool  Y        2.0      5
# 7                7       3          1  Hot Water Rad  Y        2.0      8
# ...

# %%
df.shape
# Out:
# (158957, 49)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                 0
# BATHRM                     0
# HF_BATHRM                  0
# HEAT                       0
# AC                         0
# NUM_UNITS              52261
# ROOMS                      0
# BEDRM                      0
# AYB                      271
# YR_RMDL                78029
# EYB                        0
# STORIES                52305
# SALEDATE               26770
# PRICE                  60741
# QUALIFIED                  0
# SALE_NUM                   0
# GBA                    52261
# BLDG_NUM                   0
# STYLE                  52261
# STRUCT                 52261
# GRADE                  52261
# CNDTN                  52261
# EXTWALL                52261
# ROOF                   52261
# INTWALL                52261
# KITCHENS               52262
# FIREPLACES                 0
# USECODE                    0
# LANDAREA                   0
# GIS_LAST_MOD_DTTM          0
# SOURCE                     0
# CMPLX_NUM             106696
# ...

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23        False
# 24        False
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
#           ...
# 158927    False
# 158928    False
# 158929    False
# 158930    False
# 158931    False
# 158932    False
# 158933    False
# 158934    False
# 158935    False
# 158936    False
# 158937    False
# 158938    False
# 158939    False
# 158940    False
# 158941    False
# 158942    False
# 158943    False
# 158944    False
# 158945    False
# 158946    False
# 158947    False
# 158948    False
# 158949    False
# 158950    False
# ...

# %%
df.duplicated(['FULLADDRESS'])
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23        False
# 24        False
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
#           ...
# 158927     True
# 158928     True
# 158929     True
# 158930     True
# 158931     True
# 158932     True
# 158933     True
# 158934     True
# 158935     True
# 158936     True
# 158937     True
# 158938     True
# 158939     True
# 158940     True
# 158941     True
# 158942     True
# 158943     True
# 158944     True
# 158945     True
# 158946     True
# 158947     True
# 158948     True
# 158949     True
# 158950     True
# ...

# %%
df['PRICE'].mean()
# Out:
# 931351.5949336156

# %%
#average price for house in poor condition
df[df["CNDTN"]=="Poor"]["PRICE"].mean()
# Out:
# 474262.63440860214

# %%
# df[condition]
# condition looks like df["PRICE] < 50000
df[df["PRICE"] < 50000]
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 20              20       3          1  Hot Water Rad  Y        1.0     14
# 25              25       1          0  Hot Water Rad  N        1.0      8
# 433            433       3          0  Hot Water Rad  N        3.0     11
# 638            638       2          0      Warm Cool  Y        1.0      9
# 1186          1186       2          0     Forced Air  Y        2.0      6
# 1567          1567       3          0  Hot Water Rad  N        2.0     11
# 1593          1593       1          0  Hot Water Rad  N        1.0      5
# 1916          1916       4          0  Hot Water Rad  N        2.0     12
# 2446          2446       2          0  Hot Water Rad  N        1.0     10
# 2681          2681       3          0  Hot Water Rad  N        2.0     12
# 3293          3293       2          0     Forced Air  N        2.0      7
# 3330          3330       2          1  Hot Water Rad  N        1.0      9
# ...

# %%
# average number of rooms for homes < 50000
df[df["PRICE"] < 50000]["ROOMS"].mean()
# Out:
# 4.8061056105610565

# %%
#average price of homes with 4 bathrooms
df[df["BATHRM"] == 4]["PRICE"].mean()
# Out:
# 958108.1412689285

# %%
#If the price is less than 50000 and the year it is build is 2018
(df["PRICE"]) < 50000 & (df["EYB"]==2018)
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23        False
# 24        False
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
#           ...
# 158927    False
# 158928    False
# 158929    False
# 158930    False
# 158931    False
# 158932    False
# 158933    False
# 158934    False
# 158935    False
# 158936    False
# 158937    False
# 158938    False
# 158939    False
# 158940    False
# 158941    False
# 158942    False
# 158943    False
# 158944    False
# 158945    False
# 158946    False
# 158947    False
# 158948    False
# 158949    False
# 158950    False
# ...

# %%
#To show the actual row where this condition is true
df[(df["PRICE"]) < 50000 & (df["EYB"]==2018)]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, BATHRM, HF_BATHRM, HEAT, AC, NUM_UNITS, ROOMS, BEDRM, AYB, YR_RMDL, EYB, STORIES, SALEDATE, PRICE, QUALIFIED, SALE_NUM, GBA, BLDG_NUM, STYLE, STRUCT, GRADE, CNDTN, EXTWALL, ROOF, INTWALL, KITCHENS, FIREPLACES, USECODE, LANDAREA, GIS_LAST_MOD_DTTM, SOURCE, CMPLX_NUM, LIVING_GBA, FULLADDRESS, CITY, STATE, ZIPCODE, NATIONALGRID, LATITUDE, LONGITUDE, ASSESSMENT_NBHD, ASSESSMENT_SUBNBHD, CENSUS_TRACT, CENSUS_BLOCK, WARD, SQUARE, X, Y, QUADRANT]
# Index: []
#
# [0 rows x 49 columns]

# %%
#if one or the other condition is true
df[(df["PRICE"]) < 50000| (df["EYB"]== 2015)]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, BATHRM, HF_BATHRM, HEAT, AC, NUM_UNITS, ROOMS, BEDRM, AYB, YR_RMDL, EYB, STORIES, SALEDATE, PRICE, QUALIFIED, SALE_NUM, GBA, BLDG_NUM, STYLE, STRUCT, GRADE, CNDTN, EXTWALL, ROOF, INTWALL, KITCHENS, FIREPLACES, USECODE, LANDAREA, GIS_LAST_MOD_DTTM, SOURCE, CMPLX_NUM, LIVING_GBA, FULLADDRESS, CITY, STATE, ZIPCODE, NATIONALGRID, LATITUDE, LONGITUDE, ASSESSMENT_NBHD, ASSESSMENT_SUBNBHD, CENSUS_TRACT, CENSUS_BLOCK, WARD, SQUARE, X, Y, QUADRANT]
# Index: []
#
# [0 rows x 49 columns]

# %%
#create your own condition
df

# %%
#create your own condition
df[(df["EYB"]>2015) & (df["ROOMS"]==5)]
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM        HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 3691          3691       2          1     Ht Pump  Y        1.0      5      3
# 4394          4394       4          1  Forced Air  Y        1.0      5      3
# 4395          4395       4          1  Forced Air  Y        1.0      5      3
# 4396          4396       4          1  Forced Air  Y        1.0      5      3
# 24349        24349       2          0   Warm Cool  Y        1.0      5      1
# 77874        77874       2          1  Forced Air  Y        1.0      5      2
# 77877        77877       2          1  Forced Air  Y        1.0      5      2
# 79581        79581       2          1  Forced Air  Y        1.0      5      2
# 79582        79582       2          1  Forced Air  Y        1.0      5      2
# 80028        80028       2          1  Forced Air  Y        1.0      5      2
# 80034        80034       2          1  Forced Air  Y        1.0      5      2
# ...

# %%
#averae number of rooms for homes over $100000 and built after 2010
df[(df["PRICE"] < 100000) & (df["EYB"] > 2010)]["ROOMS"].mean()
# Out:
# 7.882352941176471

# %%
df[(df["ZIPCODE"]==20001) & (df["ROOMS"]>3)]
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 994            994       1          0  Hot Water Rad  N        1.0      6
# 995            995       2          0  Hot Water Rad  N        1.0      7
# 996            996       2          0     Forced Air  Y        1.0      7
# 997            997       1          1      Warm Cool  Y        1.0      4
# 998            998       1          1  Hot Water Rad  N        1.0      5
# 999            999       1          0  Hot Water Rad  N        1.0      6
# 1000          1000       4          0     Forced Air  Y        1.0      9
# 1001          1001       2          0  Hot Water Rad  Y        1.0      4
# 1002          1002       4          1      Warm Cool  Y        1.0      9
# 1003          1003       1          1      Warm Cool  Y        1.0      5
# 1004          1004       1          1     Forced Air  Y        1.0      6
# 1005          1005       1          0  Hot Water Rad  N        1.0      5
# ...

# %%
#how many of the houses which cost less than $300000 and have more than 3 rooms are condominniums?
df[(df["PRICE"]<300000) & (df["ROOMS"]>3)& (df["SOURCE"] =="Condominium")]
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM        HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 106707      106707       2          0  Forced Air  Y        NaN      4      2
# 106708      106708       2          0  Forced Air  Y        NaN      4      2
# 106709      106709       2          0  Forced Air  Y        NaN      4      2
# 106710      106710       2          0  Forced Air  Y        NaN      4      2
# 106712      106712       2          0  Forced Air  Y        NaN      4      2
# 106713      106713       2          0  Forced Air  Y        NaN      4      2
# 106756      106756       1          1   Warm Cool  Y        NaN      5      2
# 106757      106757       1          0   Warm Cool  Y        NaN      4      1
# 106780      106780       1          0   Warm Cool  Y        NaN      4      1
# 106788      106788       1          0   Warm Cool  Y        NaN      4      1
# 106791      106791       1          0   Warm Cool  Y        NaN      4      1
# ...

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df.head()
# Out:
#    Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0           0       4          0      Warm Cool  Y        2.0      8      4
# 1           1       3          1      Warm Cool  Y        2.0     11      5
# 2           2       3          1  Hot Water Rad  Y        2.0      9      5
# 3           3       3          1  Hot Water Rad  Y        2.0      8      5
# 4           4       2          1      Warm Cool  Y        1.0     11      3
#
#       AYB  YR_RMDL   ...     LONGITUDE  ASSESSMENT_NBHD ASSESSMENT_SUBNBHD  \
# 0  1910.0   1988.0   ...    -77.040832       Old City 2   040 D Old City 2
# 1  1898.0   2007.0   ...    -77.040764       Old City 2   040 D Old City 2
# 2  1910.0   2009.0   ...    -77.040678       Old City 2   040 D Old City 2
# 3  1900.0   2003.0   ...    -77.040629       Old City 2   040 D Old City 2
# 4  1913.0   2012.0   ...    -77.039361       Old City 2   040 D Old City 2
#
# ...

# %%
#make a scatterplot
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
location = "DC_Properties.csv"
df = pd.read_csv(location)
print(df)
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 0                0       4          0      Warm Cool  Y        2.0      8
# 1                1       3          1      Warm Cool  Y        2.0     11
# 2                2       3          1  Hot Water Rad  Y        2.0      9
# 3                3       3          1  Hot Water Rad  Y        2.0      8
# 4                4       2          1      Warm Cool  Y        1.0     11
# 5                5       3          2  Hot Water Rad  Y        1.0     10
# 6                6       1          0      Warm Cool  Y        2.0      5
# 7                7       3          1  Hot Water Rad  Y        2.0      8
# 8                8       3          1      Warm Cool  Y        2.0      7
# 9                9       1          1  Hot Water Rad  Y        1.0      6
# 10              10       3          0     Forced Air  N        3.0     12
# 11              11       5          0  Hot Water Rad  Y        3.0     16
# ...

# %%
#boxplot showing stats for each characteristic
sns.boxplot(data=df)

# %%
sns.lmplot(x='PRICE', y='BATHRM', data=df)

# %%
sns.violinplot(x='PRICE', y='ROOMS', data=df)

# %%
sns.boxplot(data=df)

# %%
stats_df = df.drop(['NUM_UNITS', 'HEAT', 'AC'], axis=1)
stats_df.head()
# Out:
#    Unnamed: 0  BATHRM  HF_BATHRM  ROOMS  BEDRM     AYB  YR_RMDL   EYB  \
# 0           0       4          0      8      4  1910.0   1988.0  1972
# 1           1       3          1     11      5  1898.0   2007.0  1972
# 2           2       3          1      9      5  1910.0   2009.0  1984
# 3           3       3          1      8      5  1900.0   2003.0  1984
# 4           4       2          1     11      3  1913.0   2012.0  1985
#
#    STORIES             SALEDATE   ...     LONGITUDE ASSESSMENT_NBHD  \
# 0      3.0  2003-11-25 00:00:00   ...    -77.040832      Old City 2
# 1      3.0  2000-08-17 00:00:00   ...    -77.040764      Old City 2
# 2      3.0  2016-06-21 00:00:00   ...    -77.040678      Old City 2
# 3      3.0  2006-07-12 00:00:00   ...    -77.040629      Old City 2
# 4      3.0                  NaN   ...    -77.039361      Old City 2
#
#    ASSESSMENT_SUBNBHD  CENSUS_TRACT  CENSUS_BLOCK    WARD SQUARE          X  \
# ...

# %%
sns.boxplot(data=stats_df)

# %%
pkmn_type_colors = ['#78C850',  # Grass
                    '#F08030',  # Fire
                    '#6890F0',  # Water
                    '#A8B820',  # Bug
                    '#A8A878',  # Normal
                    '#A040A0',  # Poison
                    '#F8D030',  # Electric
                    '#E0C068',  # Ground
                    '#EE99AC',  # Fairy
                    '#C03028',  # Fighting
                    '#F85888',  # Psychic
                    '#B8A038',  # Rock
                    '#705898',  # Ghost
                    '#98D8D8',  # Ice
                    '#7038F8',  # Dragon
                   ]

# %%
plt.subplots(figsize=(10,6))
sns.swarmplot(x='AYB', y='PRICE', data=df.head(), palette=pkmn_type_colors)
